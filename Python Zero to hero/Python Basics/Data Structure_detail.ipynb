# %% [markdown]
# ## Data structures

# %%
help("if")
# Out:
# The "if" statement
# ******************
#
# The "if" statement is used for conditional execution:
#
#    if_stmt ::= "if" assignment_expression ":" suite
#                ("elif" assignment_expression ":" suite)*
#                ["else" ":" suite]
#
# It selects exactly one of the suites by evaluating the expressions one
# by one until one is found to be true (see section Boolean operations
# for the definition of true and false); then that suite is executed
# (and no other part of the "if" statement is executed or evaluated).
# If all expressions are false, the suite of the "else" clause, if
# present, is executed.
#
# Related help topics: TRUTHVALUE

# %%
# help("set")
help("dict")
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the dict keys.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |
#  |      If the key is not found, return the default if given; otherwise,
#  |      raise a KeyError.
#  |
#  |  popitem(self, /)
#  |      Remove and return a (key, value) pair as a 2-tuple.
#  |
#  |      Pairs are returned in LIFO (last-in, first-out) order.
#  |      Raises KeyError if the dict is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...)
#  |      See PEP 585
#  |
#  |  fromkeys(iterable, value=None, /)
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
list_names=["hello","world","uk","country"]
for i in list_names:
    print(i)
# Out:
# hello
# world
# uk
# country

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
class1='kiran','vikas','venkat'
type(class1)
# Out:
# tuple

# %% [markdown]
# ## Data Structures

# %% [markdown]
# <li> If i want to store more than 1 value at a time, python going to trigger <b>Data structures</b>
#
# <li> <ul> Vector or scalar
# <li>>1D - n number of rows and one column
# <li><ul>2D - contains n no.of rows and m - no. of columns
# <li>3 D  -
#
# <li> 1. List - 1D, list(), []- mutable
# <li> 2. tuple,immutable
# <li> 3. Set, -1D -To pick unique set of values
# <li> 4. Dictionary - 2D  dict(), {}, key -value pair
# <li> Array, 1D, 2D are in hommogenous in nature. -numpy
# <li> Hetrogenous file- pandas

# %%
a=[]
print(type(a))
a=[23,44,32,67,"hello","ram","python"]
''' 
C - Create
R - Read
U - Update
D - Delete

'''
print(a[:3])
# Out:
# <class 'list'>
# [23, 44, 32]

# %%
# Update 
a[3]="merry"
helllo=1
print("updated",a)
type("merry")
a.remove("python")
print(a)
# Out:
# updated [23, 44, 32, 'merry', 'python']
# [23, 44, 32, 'merry']

# %%
a.clear()

# %%
a.append("gmail")
# Out:
# ['gmail', 'gmail']

# %%
a
# Out:
# ['gmail', 'gmail']

# %% [markdown]
# ### TUPLE

# %%
tup_data=(23,44,32,67,"hello","ram","python")
type(tup_data)
# Out:
# tuple

# %%
tup_data[3]="dfds"
# Tuple are immutable
# Methods available inside the tuple
# dir(tup_data.i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tup_data[3]="dfds"
#       2 # Tuple are immutable
#       3 # Methods available inside the tuple
#       4 # dir(tup_data.i)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# dict_data={}  # Empty {} define dictionary
# type(dict_data)
dir(dict_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # dict_data={}  # Empty {} define dictionary
#       2 # type(dict_data)
# ----> 3 dir(dict_data)
#
# NameError: name 'dict_data' is not defined

# %% [markdown]
# ### SET

# %%
set_data=set()
type(set_data)
# Out:
# set

# %%
dir(set_data)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# Tuples are good in performance in terms of storage. cons- immutable.
# Tuples are more memory efficient than lists

# %% [markdown]
# ### Dictionary

# %%
#Dictionary
d={"sales":[10,2,3,4,33],"profit":(324,54,5,6)}
d['sales'][3]
# Out:
# 4

# %%
d['sales'][3]=3423
d
# Out:
# {'sales': [10, 2, 3, 3423, 33], 'profit': (324, 54, 5, 6)}

# %%
today_class={"list":a,"tuple":tup_data,"Set":set_data,"Dictionary":d}

# %%
today_class
# Out:
# {'list': ['gmail', 'gmail'],
#  'tuple': (23, 44, 32, 67, 'hello', 'ram', 'python'),
#  'Set': set(),
#  'Dictionary': {'sales': [10, 2, 3, 4, 33], 'profit': (324, 54, 5, 6)}}

# %% [markdown]
# ### DATA STRUCTURES

# %% [markdown]
# 1. Python has a clean readable syntax
# 2. DSA allows you to improve problem-solving skills
# 3. DSA and Python helps you write more efficient code
# 4. DSA gives you a better understanding of memory storage
# 5. DSA helps you handle complex programming challenges
# 6. Python is widely used in Data Science and Machine Learning

# %%
from datasets import load_dataset

# %%
# pip install datasets

# %%
dataset=load_dataset("Selvakumarduraipandian/Thirukural")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1330 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['ID', 'Adhigaram_ID', 'Paal', 'Iyal', 'Adhigaram', 'Kural', 'Transliteration', 'Vilakam', 'Couplet', 'Chapter', 'Section', 'Athigaram', 'Kalaingar_Urai', 'Parimezhalagar_Urai', 'M_Varadharajanar', 'Solomon_Pappaiya'],
#         num_rows: 1330
#     })
# })

# %%
train_dataset=dataset['train']

# %%
train_dataset
# Out:
# Dataset({
#     features: ['ID', 'Adhigaram_ID', 'Paal', 'Iyal', 'Adhigaram', 'Kural', 'Transliteration', 'Vilakam', 'Couplet', 'Chapter', 'Section', 'Athigaram', 'Kalaingar_Urai', 'Parimezhalagar_Urai', 'M_Varadharajanar', 'Solomon_Pappaiya'],
#     num_rows: 1330
# })

# %%
df=train_dataset.to_pandas()

# %%
df
# Out:
#         ID  Adhigaram_ID           Paal        Iyal        Adhigaram  \
# 0        1             1   அறத்துப்பால்  பாயிரவியல்  கடவுள் வாழ்த்து
# 1        2             1   அறத்துப்பால்  பாயிரவியல்  கடவுள் வாழ்த்து
# 2        3             1   அறத்துப்பால்  பாயிரவியல்  கடவுள் வாழ்த்து
# 3        4             1   அறத்துப்பால்  பாயிரவியல்  கடவுள் வாழ்த்து
# 4        5             1   அறத்துப்பால்  பாயிரவியல்  கடவுள் வாழ்த்து
# ...    ...           ...            ...         ...              ...
# 1325  1326           133  காமத்துப்பால்    கற்பியல்         ஊடலுவகை
# 1326  1327           133  காமத்துப்பால்    கற்பியல்         ஊடலுவகை
# 1327  1328           133  காமத்துப்பால்    கற்பியல்         ஊடலுவகை
# 1328  1329           133  காமத்துப்பால்    கற்பியல்         ஊடலுவகை
# 1329  1330           133  காமத்துப்பால்    கற்பியல்         ஊடலுவகை
#
#                                                   Kural  \
# 0     அகர முதல எழுத்தெல்லாம் ஆதி<br />பகவன் முதற்றே ...
# 1     கற்றதனால் ஆய பயனென்கொல் வாலறிவன்<br />நற்றாள் ...
# 2     மலர்மிசை ஏகினான் மாணடி சேர்ந்தார்<br />நிலமிசை...
# 3     வேண்டுதல் வேண்டாமை இலானடி சேர்ந்தார்க்கு<br />...
# 4     இருள்சேர் இருவினையும் சேரா இறைவன்<br />பொருள்ச...
# ...                                                 ...
# 1325  உணலினும் உண்டது அறல்இனிது காமம்<br />புணர்தலின...
# 1326  ஊடலில் தோற்றவர் வென்றார் அதுமன்னும்<br />கூடலி...
# 1327  ஊடிப் பெறுகுவம் கொல்லோ நுதல்வெயர்ப்பக்<br />கூ...
# 1328  ஊடுக மன்னோ ஒளியிழை யாமிரப்ப<br />நீடுக மன்னோ இரா.
# 1329  ஊடுதல் காமத்திற்கு இன்பம் அதற்கின்பம்<br />கூட...
#
#                                         Transliteration  \
# 0     Akara Mudhala  Ezhuththellaam  Aadhi  Pakavan ...
# 1     Katradhanaal Aaya  Payanenkol  Vaalarivan  Nat...
# 2     Malarmisai Ekinaan  Maanati  Serndhaar  Nilami...
# 3     Ventudhal Ventaamai  Ilaanati  Serndhaarkku  Y...
# 4     Irulser Iruvinaiyum  Seraa  Iraivan  Porulser ...
# ...                                                 ...
# 1325  Unalinum Untadhu  Aralinidhu  Kaamam  Punardha...
# 1326  Ootalil Thotravar  Vendraar  Adhumannum  Koota...
# 1327  Ootip Perukuvam  Kollo  Nudhalveyarppak  Koota...
# 1328  Ootuka Manno  Oliyizhai  Yaamirappa  Neetuka  ...
# 1329  Ootudhal Kaamaththirku  Inpam  Adharkinpam  Ko...
#
#                                                 Vilakam  \
# 0     அகரம் எழுத்துக்களுக்கு முதன்மை; ஆதிபகவன், உலகி...
# 1     தன்னைவிட அறிவில் மூத்த பெருந்தகையாளரின் முன்னே...
# 2     மலர் போன்ற மனத்தில் நிறைந்தவனைப் பின்பற்றுவோரி...
# 3     விருப்பு வெறுப்பற்றுத் தன்னலமின்றித் திகழ்கின்...
# 4     இறைவன் என்பதற்குரிய பொருளைப் புரிந்து கொண்டு ப...
# ...                                                 ...
# 1325  உணவு அருந்துவதைவிட, அருந்திய உணவு செரிப்பதிலே ...
# 1326  ஊடல் என்கிற இனிய போரில் தோற்றவர்தான் வெற்றி பெ...
# 1327  நெற்றியில் வியர்வை அரும்பிடக் கூடுவதால் ஏற்படு...
# 1328  ஒளி முகத்தழகி ஊடல் புரிவாளாக் அந்த ஊடலைத் தீர்...
# 1329  ஒருவருக்கொருவர் செல்லமாகச் சினங்கொண்டு பிரிந்த...
#
#                                                 Couplet        Chapter  \
# 0     A, as its first of letters, every speech maint...   அறத்துப்பால்
# 1     No fruit have men of all their studied lore,  ...   அறத்துப்பால்
# 2     His feet, 'Who o'er the full-blown flower hath...   அறத்துப்பால்
# 3     His foot, 'Whom want affects not, irks not gri...   அறத்துப்பால்
# 4     The men, who on the 'King's' true praised deli...   அறத்துப்பால்
# ...                                                 ...            ...
# 1325  'Tis sweeter to digest your food than 'tis to ...  காமத்துப்பால்
# 1326  In lovers' quarrels, 'tis the one that first g...  காமத்துப்பால்
# 1327  And shall we ever more the sweetness know of t...  காமத்துப்பால்
# 1328  Let her, whose jewels brightly shine, aversion...  காமத்துப்பால்
# 1329  A 'feigned aversion' coy to pleasure gives a z...  காமத்துப்பால்
#
#      Section        Athigaram  \
# 0        1.1  கடவுள் வாழ்த்து
# 1        1.2  கடவுள் வாழ்த்து
# 2        1.3  கடவுள் வாழ்த்து
# 3        1.4  கடவுள் வாழ்த்து
# 4        1.5  கடவுள் வாழ்த்து
# ...      ...              ...
# 1325   133.6        ஊடல் உவகை
# 1326   133.7        ஊடல் உவகை
# 1327   133.8        ஊடல் உவகை
# 1328   133.9        ஊடல் உவகை
# 1329  133.10        ஊடல் உவகை
#
#                                          Kalaingar_Urai  \
# 0     அகரம்   எழுத்துக்களுக்கு   முதன்மை;  ஆதிபகவன்,...
# 1     தன்னைவிட அறிவில்  மூத்த பெருந்தகையாளரின் முன்ன...
# 2     மலர் போன்ற மனத்தில் நிறைந்தவனைப் பின்பற்றுவோரி...
# 3     விருப்பு  வெறுப்பற்றுத்  தன்னலமின்றித்   திகழ்...
# 4     இறைவன்   என்பதற்குரிய   பொருளைப் புரிந்து கொண்...
# ...                                                 ...
# 1325  உணவு  அருந்துவதைவிட,  அருந்திய உணவு செரிப்பதில...
# 1326  ஊடல் என்கிற இனிய போரில் தோற்றவர்தான் வெற்றி பெ...
# 1327  நெற்றியில்   வியர்வை   அரும்பிடக் கூடுவதால் ஏற...
# 1328  ஒளி   முகத்தழகி    ஊடல்   புரிவாளாக; அந்த ஊடலை...
# 1329  ஒருவருக்கொருவர்    செல்லமாகச்    சினங்கொண்டு  ...
#
#                                     Parimezhalagar_Urai  \
# 0     எழுத்து எல்லாம் அகரம் முதல - எழுத்துக்கள் எல்ல...
# 1     கற்றதனால் ஆய பயன் என் - எல்லா நூல்களையும் கற்ற...
# 2     மலர்மிசை ஏகினான் மாண்அடி சேர்ந்தார் - மலரின் க...
# 3     வேண்டுதல் வேண்டாமை இலான் அடி சேர்ந்தார்க்கு - ...
# 4     இருள்சேர் இருவினையும் சேரா - மயக்கத்தைப் பற்றி...
# ...                                                 ...
# 1325  (இதுவும் அது.) உணலினும் உண்டது அறல் இனிது - உய...
# 1326  (இதுவும் அது.) ஊடலில் தோற்றவர் வென்றார் - காமம...
# 1327  (இதுவும் அது.) நுதல் வெயர்ப்பக் கூடலில் தோன்றி...
# 1328  (இதுவும் அது.) ஒளி இழை ஊடுக மன் - ஒளியிழையினை ...
# 1329  (இதுவும் அது) காமத்திற்கு இன்பம் ஊடுதல் - காமந...
#
#                                        M_Varadharajanar  \
# 0     எழுத்துக்கள் எல்லாம் அகரத்தை அடிப்படையாக கொண்...
# 1     தூய அறிவு வடிவாக விளங்கும் இறைவனுடைய நல்ல திரு...
# 2     அன்பரின் அகமாகிய மலரில் வீற்றிருக்கும் கடவுளின...
# 3     விருப்பு வெறுப்பு இல்லாத கடவுளின் திருவடிகளை ப...
# 4     கடவுளின் உண்மைப் புகழை விரும்பி அன்பு செலுத்து...
# ...                                                 ...
# 1325  உண்பதை விட முன் உண்ட உணவுச் செரிப்பது இன்பமானத...
# 1326  ஊடலில் தோற்றவரே வெற்றி பெற்றவர் ஆவர், அந்த உண்...
# 1327  நெற்றி வியர்க்கும் படியாக கூடுவதில் உளதாகும் இ...
# 1328  காதலி இன்னும் ஊடுவாளாக, அந்த ஊடலைத் தணிக்கும் ...
# 1329  காமத்திற்கு இன்பம் தருவது ஊடுதல் ஆகும், ஊடல் ம...
#
#                                        Solomon_Pappaiya
# 0     எழுத்துக்கள் எல்லாம் அகரத்தில் தொடங்குகின்றன; ...
# 1     தூய அறிவு வடிவானவனின் திருவடிகளை வணங்காதவர், ப...
# 2     மனமாகிய மலர்மீது சென்று இருப்பவனாகிய கடவுளின் ...
# 3     எதிலும் விருப்பு வெறுப்பு இல்லாத கடவுளின் திரு...
# 4     கடவுளின் மெய்மைப் புகழையே விரும்புபவரிடம் அறிய...
# ...                                                 ...
# 1325  உண்பதைவிட உண்டது செரிப்பது இனியது; அதுபோலக், க...
# 1326  ஊடலில் தோற்றவரே வெற்றி பெற்றவர் ஆவார்; அந்த வெ...
# 1327  நெற்றி வியர்க்கும்படி கலவியில் தோன்றும் சுகத்த...
# 1328  ஒளிமிகும் அணிகளை அணிந்த இவள் இன்னும் என்னோடு ஊ...
# 1329  காதல் நுகர்ச்சிக்கு இன்பம் ஊடுதலே அவ்வூடலுக்கு...
#
# [1330 rows x 16 columns]
