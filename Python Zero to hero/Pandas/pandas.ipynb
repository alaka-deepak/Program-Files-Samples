# %% [markdown]
# ### Pandas

# %% [markdown]
# 1. Pandas is a Python library.
#
# 2. Pandas is used to analyze and manipulate data.
#
# 3. Pandas provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data easily
# 4. Pandas is usually imported under the pd alias.

# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

myvar
type(myvar)
# Out:
# pandas.core.frame.DataFrame

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# ### Pandas Series
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.
#
# Create a simple Pandas Series from a list:

# %%
a = [1, 7, 2]
myvar = pd.Series(a)

# %% [markdown]
# 1. If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# 2. This label can be used to access a specified value.with the index argument, you can name your own labels.when you have created labels, you can access an item by referring to the label.

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# #### You can also use a key/value object, like a dictionary, when creating a Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# #### Create a Data frame into two series

# %%
# Create a DataFrame from two Series:
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# %% [markdown]
# #### Data Frame
#
# A DataFrame is a 2D labeled data structure in Python, provided by the pandas library.

# %%
myvar = pd.DataFrame(data)
myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# #### loc
# It is label-based indexing, meaning that you use row and column names to select the data.
# df.loc[row_labels, column_labels]

# %%
print(myvar.loc[0])
print(myvar.loc[[0, 1]])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40

# %%
# Add a list of names to give each row a name:
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# Overview of the DataFrame
print(df.info())

# # Summary statistics
print(df.describe())

# First few rows
print(df.head())

# Shape (rows, columns)
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000
#    Duration  Pulse  Maxpulse  Calories
# ...

# %%
# Select one column
print(df['Duration'])

# Select multiple columns
print(df[['Duration', 'Calories']])

# Select specific row by index
print(df.loc[3])  # 4th row

# Select row and column
print(df.loc[3, 'Calories'])
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# ..        ...       ...
# 164        60     290.8
# 165        60     300.0
# 166        60     310.2
# 167        75     320.4
# 168        75     330.4
#
# [169 rows x 2 columns]
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64
# 282.4

# %%
df.head(15)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0

# %%
df.tail(5)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
# Workouts longer than 45 minutes
print(df[df['Duration'] > 45])

# Workouts where Maxpulse is over 140
print(df[df['Maxpulse'] > 140])

# Workouts where Duration is 60 and Calories > 350
print(df[(df['Duration'] == 60) & (df['Calories'] > 350)])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [106 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories
# 1          60    117       145     479.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 10         60    103       147     329.3
# 46         60    109       153     387.6
# 51         80    123       146     643.1
# 53         60    118       151     486.0
# 54         30    136       175     238.0
# 55         60    121       146     450.7
# ...

# %%
# Sort by Calories (ascending)
print(df.sort_values(by='Calories'))

# Sort by Maxpulse (descending)
print(df.sort_values(by='Maxpulse', ascending=False))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 89         20     83       107      50.3
# 93         15     80       100      50.5
# 100        20     95       112      77.7
# 107        30     90       120      86.2
# 104        30     92       108      92.7
# ..        ...    ...       ...       ...
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN
#
# [169 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories
# 109       210    137       184    1860.4
# 80         30    159       182     319.2
# 54         30    136       175     238.0
# 3          45    109       175     282.4
# 58         20    153       172     226.4
# ..        ...    ...       ...       ...
# 88         45    129       103     242.0
# 22         60    130       101     300.0
# 103        90     90       100     500.4
# ...

# %%
# Add a new column: Calories burned per minute
df['CalPerMin'] = df['Calories'] / df['Duration']

# Modify existing column
df['Duration'] = df['Duration'] + 5  # Adding 5 to every duration

# %%
# Drop the new column (without modifying the original df)
df.drop(columns=['CalPerMin'], inplace=True)

# Drop a specific row
df.drop(index=2, inplace=True)  # Remove 3rd row

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          65    110       130     409.1
# 1          65    117       145     479.0
# 3          50    109       175     282.4
# 4          50    117       148     406.0
# 5          65    102       127     300.0
# ..        ...    ...       ...       ...
# 164        65    105       140     290.8
# 165        65    110       145     300.0
# 166        65    115       145     310.2
# 167        80    120       150     320.4
# 168        80    125       150     330.4
#
# [168 rows x 4 columns]

# %%
# Average Calories burned grouped by Duration
print(df.groupby('Duration')['Calories'].mean())

# Multiple aggregations
print(df.groupby('Duration').agg({
    'Pulse': 'mean',
    'Maxpulse': 'max',
    'Calories': 'sum'
}))
# Out:
# Duration
# 20       87.350000
# 25      151.600000
# 30      244.200000
# 35      192.125000
# 50      273.236364
# 65      339.670667
# 80      325.400000
# 85      643.100000
# 95      541.800000
# 125     666.833333
# 155     939.400000
# 165     943.700000
# 185     733.600000
# 215    1618.200000
# 275    1729.000000
# 305    1500.200000
# Name: Calories, dtype: float64
#                Pulse  Maxpulse  Calories
# Duration
# 20        102.000000       139     174.7
# 25        125.000000       172    1364.4
# 30        152.000000       168     244.2
# 35        109.812500       182    3074.0
# 50        107.485714       175    9016.8
# 65        106.166667       170   25475.3
# 80        122.500000       150     650.8
# 85        123.000000       146     643.1
# 95         93.750000       127    4334.4
# 125       100.000000       157    2000.5
# 155       101.500000       135    3757.6
# 165       109.500000       137    1887.4
# 185        93.666667       130    2200.8
# ...

# %%
print(df.isnull().sum())  # Check for NaNs

# # Drop missing values
df.dropna(inplace=True)

# # Fill missing values
df.fillna(0, inplace=True)
df
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
#      Duration  Pulse  Maxpulse  Calories
# 0          65    110       130     409.1
# 1          65    117       145     479.0
# 3          50    109       175     282.4
# 4          50    117       148     406.0
# 5          65    102       127     300.0
# ..        ...    ...       ...       ...
# 164        65    105       140     290.8
# 165        65    110       145     300.0
# 166        65    115       145     310.2
# 167        80    120       150     320.4
# 168        80    125       150     330.4
#
# [163 rows x 4 columns]

# %%
# Save to CSV
df.to_csv('workout_data.csv', index=False)

# Read from CSV
df_loaded = pd.read_csv('workout_data.csv')

# %%
import matplotlib.pyplot as plt

# Plot Duration vs Calories
df.plot(kind='scatter', x='Duration', y='Calories')
plt.show()

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.160907  0.005706  0.922715
# Pulse    -0.160907  1.000000  0.784970  0.024865
# Maxpulse  0.005706  0.784970  1.000000  0.203862
# Calories  0.922715  0.024865  0.203862  1.000000

# %% [markdown]
# 1. The corr() method ignores "not numeric" columns.
#
# 2. The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
# 3. The number varies from -1 to 1.
# 4. 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
# 5.  0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# 6. -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 7. 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# 8. What is a good correlation? It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.
